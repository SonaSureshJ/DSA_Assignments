# %% [markdown]
# #               Assignment on Python for Data Science

# %% [markdown]
# # 1.Read the dataset to python environment.#

# %%
import pandas as pd

# %%
iris_data=pd.read_excel(r'C:\Users\siva\Documents\iris.xls')

# %%
iris_data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #  2. Display the columns in the dataset.

# %%
iris_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # 3. Calculate the mean of each column of the dataset.

# %%
iris_data.mean(axis='index')
# Out:
# C:\Users\siva\AppData\Local\Temp\ipykernel_10804\2819540386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris_data.mean(axis='index')
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4. Check for the null values present in the dataset.

# %%
iris_data.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
iris_data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(iris_data['SL'],iris_data['PL'],s=10,marker='*',color='Blue')
plt.xlabel('SL')
plt.ylabel('PL')
plt.title('Scatter Plot',fontsize=20)
plt.show()

# %%
plt.scatter(iris_data['PW'],iris_data['SW'],s=10,marker='*',color='Blue')
plt.show()

# %%
 import seaborn as sns
sns.pairplot(iris_data)

# %%
sns.boxplot(x='SL',y='PL',data=iris_data)
# Out:
# <Axes: xlabel='SL', ylabel='PL'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='SL',data=iris_data) 
plt.show()
